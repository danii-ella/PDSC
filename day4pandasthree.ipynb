# %%
import numpy as np
import pandas as pd
import requests
# Out:
# C:\Users\Daniella\AppData\Local\Temp\ipykernel_9348\727925147.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
url_link = 'https://pokemondb.net/pokedex/all'
r = requests.get(url_link, headers ={'User-Agent':'Mozilla/5.0(Windows NT 10.0; Win64; x64) AppleWebKit/537.36(KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
read_html_pandas_data = pd.read_html(r.text)[0]
df= pd.DataFrame(read_html_pandas_data)
df
# Out:
# C:\Users\Daniella\AppData\Local\Temp\ipykernel_9348\176861189.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   read_html_pandas_data = pd.read_html(r.text)[0]
#          #                      Name            Type  Total   HP  Attack  \
# 0        1                 Bulbasaur   Grass  Poison    318   45      49
# 1        2                   Ivysaur   Grass  Poison    405   60      62
# 2        3                  Venusaur   Grass  Poison    525   80      82
# 3        3   Venusaur  Mega Venusaur   Grass  Poison    625   80     100
# 4        4                Charmander            Fire    309   39      52
# ...    ...                       ...             ...    ...  ...     ...
# 1210  1023                Iron Crown  Steel  Psychic    590   90      72
# 1211  1024    Terapagos  Normal Form          Normal    450   90      65
# ...

# %%
df[df['Type'] == 'Fire']
# Out:
#         #                       Name  Type  Total   HP  Attack  Defense  \
# 4       4                 Charmander  Fire    309   39      52       43
# 5       5                 Charmeleon  Fire    405   58      64       58
# 48     37                     Vulpix  Fire    299   38      41       40
# 50     38                  Ninetales  Fire    505   73      76       75
# 76     58                  Growlithe  Fire    350   55      70       45
# 78     59                   Arcanine  Fire    555   90     110       80
# 101    77                     Ponyta  Fire    410   50      85       55
# 103    78                   Rapidash  Fire    500   65     100       70
# 166   126                     Magmar  Fire    495   65      95       57
# 182   136                    Flareon  Fire    525   65     130       60
# 207   155                  Cyndaquil  Fire    309   39      52       43
# 208   156                    Quilava  Fire    405   58      64       58
# ...

# %%
df[(df['Type'] == 'Fire') & (df['Speed'] >85)]
# Out:
#        #                       Name  Type  Total   HP  Attack  Defense  \
# 50    38                  Ninetales  Fire    505   73      76       75
# 78    59                   Arcanine  Fire    555   90     110       80
# 101   77                     Ponyta  Fire    410   50      85       55
# 103   78                   Rapidash  Fire    500   65     100       70
# 166  126                     Magmar  Fire    495   65      95       57
# 209  157                 Typhlosion  Fire    534   78      84       78
# 307  244                      Entei  Fire    580  115     115       85
# 627  514                   Simisear  Fire    498   75      98       63
# 673  555  Darmanitan  Standard Mode  Fire    480  105     140       55
# 876  726                   Torracat  Fire    420   65      85       50
# 975  814                     Raboot  Fire    420   65      86       60
# 976  815                  Cinderace  Fire    530   80     116       75
#
#      Sp. Atk  Sp. Def  Speed
# ...

# %%
df_rate = pd.read_csv('exchange27022024.csv')
df_rate.head()
# Out:
#                  Rate Date  Currency Rate Year  Rate Month  Buying Rate  \
# 2/26/2024        US DOLLAR      2024  February   1661.8500    1662.3500
# 2/26/2024  POUNDS STERLING      2024  February   2107.8905    2108.5247
# 2/26/2024             EURO      2024  February   1803.2734    1803.8160
# 2/26/2024      SWISS FRANC      2024  February   1886.5365    1887.1041
# 2/26/2024              YEN      2024  February     11.0217      11.0250
#
#            Central Rate  Selling Rate
# 2/26/2024     1662.8500           NaN
# 2/26/2024     2109.1589           NaN
# 2/26/2024     1804.3585           NaN
# 2/26/2024     1887.6717           NaN
# 2/26/2024       11.0283           NaN

# %%
df_rate.reset_index(inplace=True)
df_rate.head()
# Out:
#        index        Rate Date  Currency Rate Year  Rate Month  Buying Rate  \
# 0  2/26/2024        US DOLLAR      2024  February   1661.8500    1662.3500
# 1  2/26/2024  POUNDS STERLING      2024  February   2107.8905    2108.5247
# 2  2/26/2024             EURO      2024  February   1803.2734    1803.8160
# 3  2/26/2024      SWISS FRANC      2024  February   1886.5365    1887.1041
# 4  2/26/2024              YEN      2024  February     11.0217      11.0250
#
#    Central Rate  Selling Rate
# 0     1662.8500           NaN
# 1     2109.1589           NaN
# 2     1804.3585           NaN
# 3     1887.6717           NaN
# 4       11.0283           NaN

# %%
df_rate.columns
# Out:
# Index(['index', 'Rate Date', 'Currency', 'Rate Year', 'Rate Month',
#        'Buying Rate', 'Central Rate', 'Selling Rate'],
#       dtype='object')

# %%
df_rate.rename({'index':'Rate Date', 'Rate Date':'Currency', 'Currency':'Rate Year', 'Rate Year':'Rate Month', 'Rate Month':'Buying Rate','Buying Rate':'Central Rate', 'Central Rate':'Selling Rate', 'Selling Rate':'None'}, axis = 1, inplace = True)

# %%
df_rate.head()
# Out:
#    Rate Date         Currency  Rate Year Rate Month  Buying Rate  \
# 0  2/26/2024        US DOLLAR       2024   February    1661.8500
# 1  2/26/2024  POUNDS STERLING       2024   February    2107.8905
# 2  2/26/2024             EURO       2024   February    1803.2734
# 3  2/26/2024      SWISS FRANC       2024   February    1886.5365
# 4  2/26/2024              YEN       2024   February      11.0217
#
#    Central Rate  Selling Rate  None
# 0     1662.3500     1662.8500   NaN
# 1     2108.5247     2109.1589   NaN
# 2     1803.8160     1804.3585   NaN
# 3     1887.1041     1887.6717   NaN
# 4       11.0250       11.0283   NaN

# %%
df_rate.drop('None',axis=1,inplace=True)
df_rate.head()
# Out:
#    Rate Date         Currency  Rate Year Rate Month  Buying Rate  \
# 0  2/26/2024        US DOLLAR       2024   February    1661.8500
# 1  2/26/2024  POUNDS STERLING       2024   February    2107.8905
# 2  2/26/2024             EURO       2024   February    1803.2734
# 3  2/26/2024      SWISS FRANC       2024   February    1886.5365
# 4  2/26/2024              YEN       2024   February      11.0217
#
#    Central Rate  Selling Rate
# 0     1662.3500     1662.8500
# 1     2108.5247     2109.1589
# 2     1803.8160     1804.3585
# 3     1887.1041     1887.6717
# 4       11.0250       11.0283

# %%
df_rate['Currency'].unique()
# Out:
# array(['US DOLLAR', 'POUNDS STERLING', 'EURO', 'SWISS FRANC', 'YEN',
#        'CFA', 'WAUA', 'RIYAL', 'DANISH KRONA', 'SDR', 'YUAN/RENMINBI',
#        'SOUTH AFRICAN RAND', 'POUND STERLING', 'DANISH KRONER',
#        'JAPANESE YEN', 'US DOLLAR ', 'YEN ', 'CFA ', 'WAUA ', 'SDR ',
#        'EURO\t', 'EURO ', 'RIYAL ', 'SWISS FRANC\t', 'SDR\t', 'NAIRA',
#        'POESO'], dtype=object)

# %%
df_rate['Currency'].replace({'US DOLLAR':'USD', 'POUNDS STERLING':'POUNDS', 'DANISH KRONA':'DANISH KRONA',
     'POUND STERLING':'POUNDS', 'DANISH KRONER':'DANISH KRONA','JAPANESE YEN':'YEN', 'US DOLLAR ':'USD', 'YEN ':'YEN', 'CFA ':'CFA', 'WAUA ':'WAUA', 'SDR ':'SDR', 'EURO\t':'EURO', 'EURO ':'EURO', 'RIYAL ':'RIYAL', 'SWISS FRANC\t':'SWISS FRANC', 'SDR\t':'SDR'}, inplace=True)
# Out:
# C:\Users\Daniella\AppData\Local\Temp\ipykernel_9348\8905715.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rate['Currency'].replace({'US DOLLAR':'USD', 'POUNDS STERLING':'POUNDS', 'DANISH KRONA':'DANISH KRONA',

# %%
df_rate['Currency'].unique()
# Out:
# array(['USD', 'POUNDS', 'EURO', 'SWISS FRANC', 'YEN', 'CFA', 'WAUA',
#        'RIYAL', 'DANISH KRONA', 'SDR', 'YUAN/RENMINBI',
#        'SOUTH AFRICAN RAND', 'NAIRA', 'POESO'], dtype=object)

# %%
df_rate['Rate Date'] = pd.to_datetime(df_rate['Rate Date'])
df_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54387 entries, 0 to 54386
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rate Date     54387 non-null  datetime64[ns]
#  1   Currency      54387 non-null  object
#  2   Rate Year     54387 non-null  int64
#  3   Rate Month    54387 non-null  object
#  4   Buying Rate   54387 non-null  float64
#  5   Central Rate  54387 non-null  float64
#  6   Selling Rate  54387 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 2.9+ MB

# %%
df_rate[(df_rate['Rate Date']>= pd.Timestamp(2023,1,1)) & (df_rate['Rate Date'] <= pd.Timestamp(2023,2,28)) & (df_rate['Currency'] == 'USD')]
# Out:
#       Rate Date Currency  Rate Year Rate Month  Buying Rate  Central Rate  \
# 2837 2023-02-28      USD       2023   February       459.97        460.47
# 2849 2023-02-27      USD       2023   February       459.97        460.47
# 2861 2023-02-24      USD       2023   February       459.95        460.45
# 2873 2023-02-23      USD       2023   February       459.94        460.44
# 2884 2023-02-22      USD       2023   February       459.94        460.44
# 2896 2023-02-21      USD       2023   February       459.97        460.47
# 2908 2023-02-20      USD       2023   February       459.97        460.47
# 2920 2023-02-17      USD       2023   February       460.00        460.50
# 2932 2023-02-16      USD       2023   February       460.04        460.54
# 2944 2023-02-15      USD       2023   February       460.05        460.55
# 2956 2023-02-14      USD       2023   February       460.06        460.56
# 2968 2023-02-13      USD       2023   February       460.06        460.56
# ...

# %%
df_rate = pd.read_csv('exchange27022024.csv')
df_rate.head()
# Out:
#                  Rate Date  Currency Rate Year  Rate Month  Buying Rate  \
# 2/26/2024        US DOLLAR      2024  February   1661.8500    1662.3500
# 2/26/2024  POUNDS STERLING      2024  February   2107.8905    2108.5247
# 2/26/2024             EURO      2024  February   1803.2734    1803.8160
# 2/26/2024      SWISS FRANC      2024  February   1886.5365    1887.1041
# 2/26/2024              YEN      2024  February     11.0217      11.0250
#
#            Central Rate  Selling Rate
# 2/26/2024     1662.8500           NaN
# 2/26/2024     2109.1589           NaN
# 2/26/2024     1804.3585           NaN
# 2/26/2024     1887.6717           NaN
# 2/26/2024       11.0283           NaN

# %%
#merge, concat, save to csv, save to excel, save to multiple excel sheet
#merge works just like it would in mysql, it is used to join only 2 tables
USD_table = df_rate[df_rate['Currency'] == 'USD']
EURO_table = df_rate[df_rate['Currency'] == 'EURO']
POUNDS_table = df_rate[df_rate['Currency'] == 'POUNDS']
NAIRA_table = df_rate[df_rate['Currency'] == 'NAIRA']

# %%
#outer: used for merging tables that have the same heading
df_merge = USD_table.merge(EURO_table, how= 'outer')
df_merge
# Out:
# Empty DataFrame
# Columns: [Rate Date, Currency, Rate Year, Rate Month, Buying Rate, Central Rate, Selling Rate]
# Index: []

# %%
#concatenation(used to join more than 2 tables)
alldf = pd.concat([USD_table, EURO_table, POUNDS_table, NAIRA_table], axis=0)
alldf
# Out:
# Empty DataFrame
# Columns: [Rate Date, Currency, Rate Year, Rate Month, Buying Rate, Central Rate, Selling Rate]
# Index: []

# %%
df_rate
# Out:
#                   Rate Date  Currency Rate Year  Rate Month  Buying Rate  \
# 2/26/2024         US DOLLAR      2024  February   1661.8500    1662.3500
# 2/26/2024   POUNDS STERLING      2024  February   2107.8905    2108.5247
# 2/26/2024              EURO      2024  February   1803.2734    1803.8160
# 2/26/2024       SWISS FRANC      2024  February   1886.5365    1887.1041
# 2/26/2024               YEN      2024  February     11.0217      11.0250
# ...                     ...       ...       ...         ...          ...
# 12/10/2001              CFA      2001  December      0.1514       0.1521
# 12/10/2001             EURO      2001  December     99.3787      99.8230
# 12/10/2001             WAUA      2001  December    138.8876     139.5084
# 12/10/2001        US DOLLAR      2001  December    111.8500     112.3500
# 12/10/2001              YEN      2001  December      0.8881       0.8921
#
#             Central Rate  Selling Rate
# 2/26/2024      1662.8500           NaN
# ...

# %%
#how to save to csv
alldf.to_csv('Rate.csv', index=False)

# %%
#how to save to excel
alldf.to_excel('Rate.xlsx', index=False, sheet_name= 'EXCHANGERATE')

# %%
with pd.ExcelWriter('ALLCURR_RATE.xlsx', engine= 'xlsxwriter') as writer:
    USD_table.to_excel(writer, index= False, sheet_name= 'USD', engine='xlsxwriter')
    EURO_table.to_excel(writer, index= False, sheet_name= 'EURO', engine='xlsxwriter')
    POUNDS_table.to_excel(writer, index= False, sheet_name= 'POUNDS', engine='xlsxwriter')
    NAIRA_table.to_excel(writer, index= False, sheet_name= 'NAIRA', engine='xlsxwriter')
